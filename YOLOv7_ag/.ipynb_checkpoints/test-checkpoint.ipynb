# %%
from detect_perso import run_detect_perso
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/vic/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/vic/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/vic/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_92987/490005120.py", line 1, in <module>
#     from detect_perso import run_detect_perso
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/YOLOv7_ag/detect_perso.py", line 8, in <module>
#     import torch
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /mnt/2210B8B210B88E73/Documents/Ing 3/PFE/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# 2026-03-31 16:19:39.843439: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-31 16:19:39.852488: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774966779.862572   92987 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774966779.865605   92987 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774966779.874042   92987 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774966779.874056   92987 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774966779.874057   92987 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774966779.874058   92987 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-31 16:19:39.876861: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
directory, detections = run_detect_perso(source='inference/images', weights=['runs/train/yolov7-ag/weights/best.pt'],
                                         conf_thres=0.25, img_size=640, save_csv=False, save_img=True)
# print(f"detections{detections}")
# print(f"directory{directory}")
# Out:
# YOLOR 🚀 2025-11-28 torch 2.2.2+cu121 CPU
# Fusing layers...
# Model Summary: 328 layers, 37167174 parameters, 6194944 gradients, 104.1 GFLOPS
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
# Processing images: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:06<00:00,  1.19it/s]
# The output with the result is saved in :runs/detect/exp24
# Sauvegarde de 404 détections dans runs/detect/exp24/all_detections_results.csv
# Sauvegarde CSV terminée !
# Done. (6.750s)

# %%
df = pd.DataFrame(detections)
print(df.head())
# Out:
#           id  class_id class_name  confidence  x_min_pixel  y_min_pixel  \
# 0  AIX034925         0       leaf      0.2633         3406         4585
# 1  AIX034925         2       stem      0.3521          204         4044
# 2  AIX034925         0       leaf      0.3577         3485         4272
# 3  AIX034925         0       leaf      0.3996          746         1892
# 4  AIX034925         2       stem      0.4078          792         3234
#
#    x_max_pixel  y_max_pixel
# 0         3482         4639
# 1         1101         4370
# 2         3573         4398
# 3          993         1986
# 4         1051         4460

# %%
from PIL import Image
PATH = '/mnt/2210B8B210B88E73/Documents/Ing 3/PFE/data/Data_Projet/mission_herbonaute_2000/'
def crop_detection(df_row, image_path_col='id'):


    image_id = df_row[image_path_col]
    x_min = int(df_row['x_min_pixel'])
    y_min = int(df_row['y_min_pixel'])
    x_max = int(df_row['x_max_pixel'])
    y_max = int(df_row['y_max_pixel'])
    
    print(x_min, x_max, y_min, y_max)
    
    image_path = PATH+image_id +".jpg"
    
    try:
        original_image = Image.open(image_path)
    except FileNotFoundError:
        print(f"Le fichier image n'a pas été trouvé à : {image_path}")
        return None
    
    print(f"original image size {original_image.size}")
    cropped_image = original_image.crop((x_min, y_min, x_max, y_max))
    print(image_id)
    return cropped_image

# %%
crop_detection(df.iloc[3]).show()
# Out:
# 746 993 1892 1986
# original image size (3666, 4814)
# AIX034925
