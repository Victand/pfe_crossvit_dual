# %%
import yaml

CONFIG_PATH = "../config/parameters.yaml"

# %%
# Print the training config as a dict, to past in kaggle_run.ipynb

config = yaml.load(open(CONFIG_PATH, "r"), Loader=yaml.SafeLoader)
print(f"parameters = {config["training"]}")
# Out:
# parameters = {'resume_path': None, 'lr': 0.0001, 'epochs': 50, 'patience': 10, 'batch_size': 8, 'alphas': [1.0, 1.0, 5.0, 1.0, 1.0, 1.0, 0.2], 'dataset': {'data_dir': 'data/genera', 'transforms': ['random_crop', 'random_hflip', 'random_grayscale', 'color_jitter', 'random_erase'], 'use_yolo_weights': True, 'train_split': 0.8, 'n_samples': None, 'num_workers': 0, 'precompute': True, 'use_cache': True, 'store_cache': True, 'weighted_patches': True, 'weight_function': 'linear', 'num_patches': 16, 'patch_quotas': {0: 4, 1: 0, 2: 10, 3: 2, 4: 0, 5: 0, 6: 0}}, 'model': {'model_name': 'dual_crossvit_yolo', 'crossvit': 'crossvit_15_224', 'drop_rate': 0.1}}
