# %%
import yaml

CONFIG_PATH = "../config/parameters.yaml"

# %%
# Print the training config as a dict, to past in kaggle_run.ipynb

config = yaml.load(open(CONFIG_PATH, "r"), Loader=yaml.SafeLoader)
print(config["training"])
# Out:
# {'resume_path': None, 'lr': 3e-05, 'epochs': 50, 'patience': 10, 'batch_size': 32, 'alphas': [1.0, 1.0, 5.0, 1.0, 1.0, 1.0, 0.2], 'dataset': {'classes': ['no_epines', 'epines'], 'paths': ['original', 'segmented'], 'transforms': ['random_crop', 'random_hflip', 'random_grayscale', 'color_jitter', 'gaussian_blur', 'random_affine', 'random_erase'], 'use_yolo_weights': True, 'n_samples': None, 'num_workers': 0, 'precompute': True, 'store_cache': True, 'weighted_patches': True, 'weight_function': 'linear', 'num_patches': 16, 'patch_quotas': {0: 4, 1: 0, 2: 10, 3: 2, 4: 0, 5: 0, 6: 0}}, 'model': {'model_name': 'dual_crossvic', 'cross_vit': 'crossvit_tiny_224', 'img_size': [224, 224], 'patch_size': [16, 16], 'embed_dim': [192, 384], 'depth': [[1, 5, 0], [1, 5, 0], [1, 5, 0]], 'num_heads': [6, 6], 'mlp_ratio': [3.0, 3.0, 1.0]}}
